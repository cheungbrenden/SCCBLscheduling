# %%
import pandas as pd

# %%
file = pd.read_csv("meet.csv")
file.head(21)
school_matchups = []
# Out:
#     Unnamed: 0     Unnamed: 1     Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0          NaN            NaN         WINNER         NaN        NaN
# 1          NaN  UCLA vs. UCSB           UCSB         NaN         MS
# 2          NaN   UCSD vs. UCR           UCSD         NaN        NaN
# 3          NaN            NaN            NaN         NaN        NaN
# 4          NaN           vs.       by points         NaN        NaN
# 5          NaN           vs.             NaN         NaN         WS
# 6          NaN   UCLA vs. CPP           UCLA         NaN        NaN
# 7          NaN            NaN            NaN         NaN        NaN
# 8          NaN   UCSD vs. CPP           UCSD         NaN        NaN
# 9          NaN           vs.             NaN         NaN         MD
# 10         NaN           vs.             NaN         NaN        NaN
# 11         NaN            NaN            NaN         NaN        NaN
# 12         NaN   UCSB vs. UCI           UCSB         NaN        NaN
# ...

# %%
UCLA_UCSB_df = file.iloc[0:21, 6:8] 
UCLA_UCSB_df = UCLA_UCSB_df[UCLA_UCSB_df.index % 4 != 0]
UCLA_UCSB_df.head(20)
# Out:
#                     Unnamed: 6                Unnamed: 7
# 1                Daniel Bielin                Jerry Wang
# 2                William Zhang               Clarence Un
# 3                    Andy Wang                 Edwin Yee
# 5               Isabelle Rusli              Jessica Wang
# 6                   Julie Yang                Sydney Lim
# 7                  Angela Song                Crystal Le
# 9    Daniel Bielin/Andrew Wang    Jerry Wang/Clarence Un
# 10  Yunus Chang/Brenden Chueng   Zach Streifer/Thomas Yu
# 11         Andy Wang/Harry Qin  Samuel Fong/David Qiguan
# 13  Isabelle Rusli/Angela Song   Jessica Wang/Junyu Deng
# 14      Kyra Sunil/Isa Griffis   Cori Yim/Emily Lombardi
# 15           Emily La/Kelly Ha     Yongsi Zhu/Crystal Le
# 17      William Zhang/Rinna Yu  Zach Streifer/Junyu Deng
# 18        Arnold He/Hallie Hou      Thomas Yu/Sydney Lim
# 19       Yu-Chen Lung/Emily La  Edwin Yee/Emily Lombardi

# %%
print(UCLA_UCSB.iterrows())
# Out:
# <generator object DataFrame.iterrows at 0x000001FDF91CA5F0>

# %%
for index, row in UCLA_UCSB.iterrows():
    print(row[0], row[1])
# Out:
# Daniel Bielin Jerry Wang
# William Zhang Clarence Un
# Andy Wang Edwin Yee
# Isabelle Rusli Jessica Wang
# Julie Yang Sydney Lim
# Angela Song Crystal Le
# Daniel Bielin/Andrew Wang Jerry Wang/Clarence Un
# Yunus Chang/Brenden Chueng Zach Streifer/Thomas Yu
# Andy Wang/Harry Qin Samuel Fong/David Qiguan
# Isabelle Rusli/Angela Song Jessica Wang/Junyu Deng
# Kyra Sunil/Isa Griffis Cori Yim/Emily Lombardi
# Emily La/Kelly Ha Yongsi Zhu/Crystal Le
# William Zhang/Rinna Yu Zach Streifer/Junyu Deng
# Arnold He/Hallie Hou Thomas Yu/Sydney Lim
# Yu-Chen Lung/Emily La Edwin Yee/Emily Lombardi
